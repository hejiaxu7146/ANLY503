# %%
import pandas as pd
import numpy as np
df = pd.read_csv("movies.csv")
df = df.dropna()
df = df[df.astype(str)["genres"] != '[]']
df = df[df.astype(str)["keywords"] != '[]']
df = df[df.astype(str)["production_companies"] != '[]']
df = df[df.astype(str)["production_countries"] != '[]']
df = df[df.astype(str)["spoken_languages"] != '[]']
df.head(11)
# Out:
#        budget                                             genres  \
# 0   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1   300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2   245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3   250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4   260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5   258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6   260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7   280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8   250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9   250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 11  200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
#
#                                              homepage      id  \
# 0                         http://www.avatarmovie.com/   19995
# ...

# %%
df.shape
# Out:
# (1407, 20)

# %%
import ast
gen = []
for w in df["genres"]:
    w = ast.literal_eval(w)
    a = w[0]["name"]
    gen.append(a)
    #print(w[0]["name"])

# %%
d = df["keywords"][0]
d
# Out:
# '[{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]'

# %%
type(d)
# Out:
# str

# %%
import ast
dd = ast.literal_eval(d)
dd
# Out:
# [{'id': 1463, 'name': 'culture clash'},
#  {'id': 2964, 'name': 'future'},
#  {'id': 3386, 'name': 'space war'},
#  {'id': 3388, 'name': 'space colony'},
#  {'id': 3679, 'name': 'society'},
#  {'id': 3801, 'name': 'space travel'},
#  {'id': 9685, 'name': 'futuristic'},
#  {'id': 9840, 'name': 'romance'},
#  {'id': 9882, 'name': 'space'},
#  {'id': 9951, 'name': 'alien'},
#  {'id': 10148, 'name': 'tribe'},
#  {'id': 10158, 'name': 'alien planet'},
#  {'id': 10987, 'name': 'cgi'},
#  {'id': 11399, 'name': 'marine'},
#  {'id': 13065, 'name': 'soldier'},
#  {'id': 14643, 'name': 'battle'},
#  {'id': 14720, 'name': 'love affair'},
#  {'id': 165431, 'name': 'anti war'},
#  {'id': 193554, 'name': 'power relations'},
#  {'id': 206690, 'name': 'mind and soul'},
#  {'id': 209714, 'name': '3d'}]

# %%
cleanmovie = pd.DataFrame()
cleanmovie["genres"] = gen
cleanmovie["genres"]
# Out:
# 0                Action
# 1             Adventure
# 2                Action
# 3                Action
# 4                Action
# 5               Fantasy
# 6             Animation
# 7                Action
# 8             Adventure
# 9                Action
# 10            Adventure
# 11            Adventure
# 12               Action
# 13               Action
# 14      Science Fiction
# 15            Adventure
# 16               Action
# 17               Action
# 18               Action
# 19               Action
# 20            Adventure
# 21            Adventure
# 22                Drama
# 23            Adventure
# 24               Action
# 25               Action
# 26               Action
# 27               Action
# 28               Family
# 29      Science Fiction
#              ...
# 1377              Drama
# 1378              Music
# 1379             Comedy
# 1380             Comedy
# 1381              Drama
# 1382           Thriller
# 1383              Drama
# ...

# %%
import ast
com = []
for w in df["production_companies"]:
    w = ast.literal_eval(w)
    a = w[0]["name"]
    com.append(a)
    #print(w[0]["name"])
len(com)
# Out:
# 1407

# %%
cleanmovie["companies"] = com

# %%
import ast
cou = []
for w in df["production_countries"]:
    w = ast.literal_eval(w)
    a = w[0]["name"]
    cou.append(a)
    #print(w[0]["name"])
len(cou)
# Out:
# 1407

# %%
cleanmovie["countries"] = cou

# %%
import ast
lan = []
for w in df["spoken_languages"]:
    w = ast.literal_eval(w)
    a = w[0]["name"]
    lan.append(a)
    #print(w[0]["name"])
len(lan)
cleanmovie["languages"] = lan

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
cleanmovie["budget"] = df["budget"]
cleanmovie["keywords"] = df["keywords"]
cleanmovie['title'] = df['title']
cleanmovie['overview'] = df['overview']
cleanmovie['popularity'] = df['popularity']
cleanmovie['release_date'] = df['release_date']
cleanmovie['revenue'] = df['revenue']
cleanmovie['runtime'] = df['runtime']
cleanmovie['release_date'] = df['release_date']
cleanmovie['tagline'] = df['tagline']
cleanmovie['vote_average'] = df['vote_average']

# %%
cleanmovie.columns
# Out:
# Index(['genres', 'companies', 'countries', 'languages', 'budget', 'keywords',
#        'title', 'overview', 'popularity', 'release_date', 'revenue', 'runtime',
#        'tagline', 'vote_average'],
#       dtype='object')

# %%
cleanmovie.keywords[0]
# Out:
# '[{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]'

# %%
import ast
key = []
for w in df["keywords"]:
    w = ast.literal_eval(w)
    names = []
    for i in range(len(w)):
        a = w[i]["name"]
        names.append(a)
    key.append(names)
        #print(w[0]["name"])
len(key)
# Out:
# 1407

# %%
key[0]
# Out:
# ['culture clash',
#  'future',
#  'space war',
#  'space colony',
#  'society',
#  'space travel',
#  'futuristic',
#  'romance',
#  'space',
#  'alien',
#  'tribe',
#  'alien planet',
#  'cgi',
#  'marine',
#  'soldier',
#  'battle',
#  'love affair',
#  'anti war',
#  'power relations',
#  'mind and soul',
#  '3d']

# %%
cleanmovie["keywords"] = key
cleanmovie["keywords"][0]
# Out:
# ['culture clash',
#  'future',
#  'space war',
#  'space colony',
#  'society',
#  'space travel',
#  'futuristic',
#  'romance',
#  'space',
#  'alien',
#  'tribe',
#  'alien planet',
#  'cgi',
#  'marine',
#  'soldier',
#  'battle',
#  'love affair',
#  'anti war',
#  'power relations',
#  'mind and soul',
#  '3d']

# %%
cleanmovie.columns
# Out:
# Index(['genres', 'companies', 'countries', 'languages', 'budget', 'keywords',
#        'title', 'overview', 'popularity', 'release_date', 'revenue', 'runtime',
#        'tagline', 'vote_average'],
#       dtype='object')

# %%
cleanmovie.to_csv("cleanmoviefinal.csv", index = False)

# %%
df.to_csv("test.csv", index=False)

# %%
df["genres"] = gen
df["companies"] = com
df["countries"] = cou
df["languages"] = lan
df["keywords"] = key
df.to_csv("test1.csv", index=False)

# %%
import pandas as pd
dfmovie = pd.read_csv("test1.csv")
dfmovie.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'companies', 'countries', 'languages'],
#       dtype='object')

# %%
dfmovie = dfmovie.drop(["homepage", "id", "original_title", 'production_companies', 
              'production_countries', 'spoken_languages', 'status',
             'vote_count'], axis =1)

# %%
dfmovie.to_csv("finalmovie.csv", index=False)

# %%
import pandas as pd
m = pd.read_csv("finalmovie.csv")
m.head()
# Out:
#       budget     genres                                           keywords  \
# 0  237000000     Action  ['culture clash', 'future', 'space war', 'spac...
# 1  300000000  Adventure  ['ocean', 'drug abuse', 'exotic island', 'east...
# 2  245000000     Action  ['spy', 'based on novel', 'secret agent', 'seq...
# 3  250000000     Action  ['dc comics', 'crime fighter', 'terrorist', 's...
# 4  260000000     Action  ['based on novel', 'mars', 'medallion', 'space...
#
#   original_language                                           overview  \
# 0                en  In the 22nd century, a paraplegic Marine is di...
# 1                en  Captain Barbossa, long believed to be dead, ha...
# 2                en  A cryptic message from Bond’s past sends him o...
# 3                en  Following the death of District Attorney Harve...
# 4                en  John Carter is a war-weary, former military ca...
#
#    popularity release_date     revenue  runtime  \
# ...

# %%
mnew = pd.DataFrame()

# %%
mk = m["keywords"][0]
mk
# Out:
# "['culture clash', 'future', 'space war', 'space colony', 'society', 'space travel', 'futuristic', 'romance', 'space', 'alien', 'tribe', 'alien planet', 'cgi', 'marine', 'soldier', 'battle', 'love affair', 'anti war', 'power relations', 'mind and soul', '3d']"

# %%
import ast
mk = ast.literal_eval(mk)
mk[0]
# Out:
# 'culture clash'

# %%
fw = []
for k in m["keywords"]:
    k = ast.literal_eval(k)
    fw.append(k[0])
fw
# Out:
# ['culture clash',
#  'ocean',
#  'spy',
#  'dc comics',
#  'based on novel',
#  'dual identity',
#  'hostage',
#  'marvel comic',
#  'witch',
#  'dc comics',
#  'killing',
#  'witch',
#  'texas',
#  'saving the world',
#  'new york',
#  'sea',
#  'time travel',
#  'corruption',
#  'loss of father',
#  'robin hood',
#  'elves',
#  'england',
#  'shipwreck',
#  'civil war',
#  'monster',
#  'spy',
#  'dual identity',
#  'terrorist',
#  'based on novel',
#  'egypt',
#  'sequel',
#  'circus',
#  'obsession',
#  'artificial intelligence',
#  'car race',
#  'dc comics',
#  'hostage',
#  'saving the world',
#  'car race',
#  'dystopia',
#  '1970s',
#  'based on fairy tale',
#  'persia',
#  'dystopia',
#  'moon',
#  'saving the world',
#  'tyrannosaurus rex',
#  'scotland',
#  'romantic comedy',
#  'civilization',
#  'holiday',
#  'jupiter',
#  'africa',
#  'mutant',
#  'dc comics',
#  'alien',
#  'middle east',
#  'library',
#  'dc comics',
#  'father son relationship',
#  'deja vu',
# ...

# %%
mnew["keywords"] = fw
mnew.shape
# Out:
# (1407, 1)

# %%
mnew["genres"] = m["genres"]
mnew.shape
# Out:
# (1407, 2)

# %%
netw = mnew.groupby(['keywords', 'genres']).size().reset_index(name='counts')

# %%
netw.head()
# Out:
#   keywords       genres  counts
# 0    1970s       Action       1
# 1    1970s    Adventure       1
# 2    1970s       Comedy       1
# 3    1970s  Documentary       1
# 4    1970s        Drama       2

# %%
netw.to_csv("networkdata.csv",index = False)

# %%
net1 = netw[netw["counts"] > 1]
net1.shape
# Out:
# (206, 3)

# %%
net1.columns = ["SourceName", "TargetName", "Weight"]
net1.head()
# Out:
#            SourceName TargetName  Weight
# 4               1970s      Drama       2
# 8         adolescence  Adventure       2
# 25           airplane     Action       2
# 28            alcohol     Comedy       5
# 40  american football     Comedy       3

# %%
net1.to_csv("finalnetworkdata.csv",index = False)

# %%
import pandas as pd
from datetime import datetime
heat = pd.read_csv("finalmovie.csv")
heat = heat.sort_values(by = ['release_date'])
heat = heat[730:]
d = heat["release_date"]
heat["juest_date"] = pd.to_datetime(d)
heat["year"] = heat["juest_date"].map(lambda x: x.year)
heat["month"] = heat["juest_date"].map(lambda x: x.month)

# %%
heat.head(10)
# Out:
#          budget     genres                                           keywords  \
# 578    40000000     Comedy   ['work ethic', 'tv morning show', 'tv reporter']
# 1075   10000000     Horror       ['claustrophobia', 'trapped in an elevator']
# 758    26000000     Horror  ['angel', 'diner', 'religion', 'apocalypse', '...
# 1163    7000000      Drama  ['loss of mother', 'clerk', 'grocery', 'loss o...
# 460    52000000     Action  ['paris', 'cia', 'undercover', 'explosive', 'p...
# 456    52000000     Comedy  ['flower', 'married couple', 'florist', 'kiss'...
# 107   150000000      Drama  ['father son relationship', 'victorian england...
# 1120   12000000      Drama                                      ['bollywood']
# 990    12000000  Adventure  ['roman empire', 'ancient rome', 'ancient worl...
# 277    80000000      Drama  ['based on novel', 'island', 'hurricane', 'inv...
#
#      original_language                                           overview  \
# ...

# %%
heatn = pd.DataFrame()
heatn["year"] = heat["year"]
heatn["month"] = heat["month"]
heatn["revenue"] = heat["revenue"]
heatn.head()
# Out:
#       year  month   revenue
# 578   2010      1  58785180
# 1075  2010      1  33583175
# 758   2010      1  67918658
# 1163  2010      1    382946
# 460   2010      2  52826594

# %%
#heatn = heatn.groupby(["year", "month"]).agg({"revenue": "sum"})
#heatn.head(10)
heatn["revenue"] = heatn.groupby(['year','month']).revenue.transform('sum')
heatn = heatn.drop_duplicates(subset=['year', 'month'], keep = "last")
heatn.head(10)
# Out:
#       year  month     revenue
# 1163  2010      1   160669959
# 608   2010      2   668860396
# 614   2010      3  2074370553
# 1106  2010      4  1202429291
# 1085  2010      5  1525020145
# 110   2010      6  2837580736
# 267   2010      7  2305579111
# 1303  2010      8  1171778624
# 1239  2010      9  1571729949
# 1248  2010     10   740910484

# %%
heatn.shape
# Out:
# (81, 3)

# %%
heatn = heatn[0:72]
heatn.shape
# Out:
# (72, 3)

# %%
heatn.to_csv("heatdata.csv", index=False)

# %%
import pandas as pd
p = pd.read_csv("finalmovie.csv")
shiny = pd.DataFrame()
shiny["genres"] = p["genres"]
shiny["popularity"] = p["popularity"]
shiny["revenue"] = p["revenue"]
shiny["runtime"] = p["runtime"]
shiny["vote_average"] = p["vote_average"]
shiny["countries"] = p["countries"]
shiny.head(10)
# Out:
#       genres  popularity     revenue  runtime  vote_average  \
# 0     Action  150.437577  2787965087    162.0           7.2
# 1  Adventure  139.082615   961000000    169.0           6.9
# 2     Action  107.376788   880674609    148.0           6.3
# 3     Action  112.312950  1084939099    165.0           7.6
# 4     Action   43.926995   284139100    132.0           6.1
# 5    Fantasy  115.699814   890871626    139.0           5.9
# 6  Animation   48.681969   591794936    100.0           7.4
# 7     Action  134.279229  1405403694    141.0           7.3
# 8  Adventure   98.885637   933959197    153.0           7.4
# 9     Action  155.790452   873260194    151.0           5.7
#
#                   countries
# 0  United States of America
# 1  United States of America
# 2            United Kingdom
# 3  United States of America
# 4  United States of America
# 5  United States of America
# 6  United States of America
# 7  United States of America
# 8            United Kingdom
# ...

# %%
gen = shiny
coun = shiny
gen["revenue"] = gen.groupby(['genres']).revenue.transform('mean')
gen["popularity"] = gen.groupby(['genres']).popularity.transform('mean')
gen["runtime"] = gen.groupby(['genres']).runtime.transform('mean')
gen["vote_average"] = gen.groupby(['genres']).vote_average.transform('mean')
gen.head(10)
# Out:
#       genres  popularity       revenue     runtime  vote_average  \
# 0     Action   51.771856  2.442343e+08  113.371308      6.208017
# 1  Adventure   58.284160  3.209249e+08  117.281879      6.500671
# 2     Action   51.771856  2.442343e+08  113.371308      6.208017
# 3     Action   51.771856  2.442343e+08  113.371308      6.208017
# 4     Action   51.771856  2.442343e+08  113.371308      6.208017
# 5    Fantasy   51.552524  2.407224e+08  110.440000      6.312000
# 6  Animation   49.628852  3.740684e+08   92.847458      6.416949
# 7     Action   51.771856  2.442343e+08  113.371308      6.208017
# 8  Adventure   58.284160  3.209249e+08  117.281879      6.500671
# 9     Action   51.771856  2.442343e+08  113.371308      6.208017
#
#                   countries
# 0  United States of America
# 1  United States of America
# 2            United Kingdom
# 3  United States of America
# 4  United States of America
# 5  United States of America
# 6  United States of America
# ...

# %%
coun["revenue"] = coun.groupby(['countries']).revenue.transform('mean')
coun["popularity"] = coun.groupby(['countries']).popularity.transform('mean')
coun["runtime"] = coun.groupby(['countries']).runtime.transform('mean')
coun["vote_average"] = coun.groupby(['countries']).vote_average.transform('mean')
coun.head(10)
# Out:
#       genres  popularity       revenue     runtime  vote_average  \
# 0     Action   36.550266  1.584353e+08  108.680530      6.313562
# 1  Adventure   36.550266  1.584353e+08  108.680530      6.313562
# 2     Action   38.937610  1.687388e+08  111.489385      6.386948
# 3     Action   36.550266  1.584353e+08  108.680530      6.313562
# 4     Action   36.550266  1.584353e+08  108.680530      6.313562
# 5    Fantasy   36.550266  1.584353e+08  108.680530      6.313562
# 6  Animation   36.550266  1.584353e+08  108.680530      6.313562
# 7     Action   36.550266  1.584353e+08  108.680530      6.313562
# 8  Adventure   38.937610  1.687388e+08  111.489385      6.386948
# 9     Action   36.550266  1.584353e+08  108.680530      6.313562
#
#                   countries
# 0  United States of America
# 1  United States of America
# 2            United Kingdom
# 3  United States of America
# 4  United States of America
# 5  United States of America
# 6  United States of America
# ...

# %%
gen = gen.drop_duplicates(subset=['genres'], keep = "last")
coun = coun.drop_duplicates(subset=['countries'], keep = "last")

# %%
gen.shape
# Out:
# (20, 6)

# %%
coun.shape
# Out:
# (41, 6)

# %%
coun = coun.drop('genres', 1)
gen = gen.drop('countries', 1)
coun.to_csv("coun.csv", index=False)
gen.to_csv("gen.csv", index=False)
